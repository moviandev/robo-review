# %%
#%pip install tabulate
import sys
import os

project_root = os.path.abspath(os.path.join(os.path.abspath('..'), '..', '..')) 
sys.path.append(project_root)

from models.classifiers.classifier_model_linearSVC import run_sentiment_pipeline

# %%
run_sentiment_pipeline()
# Out:
# Processing DataFrame from '1429_1.csv'...
# Finished processing '1429_1.csv'. Found 34660 rows.
# Processing DataFrame from 'Datafiniti_Amazon_Consumer_Reviews_of_Amazon_Products.csv'...
# Finished processing 'Datafiniti_Amazon_Consumer_Reviews_of_Amazon_Products.csv'. Found 5000 rows.
# Processing DataFrame from 'Datafiniti_Amazon_Consumer_Reviews_of_Amazon_Products_May19.csv'...
# Finished processing 'Datafiniti_Amazon_Consumer_Reviews_of_Amazon_Products_May19.csv'. Found 28332 rows.
#
# Merging all datasets...
# Total rows after merge: 67992
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 sentiment_analysis = run_sentiment_pipeline()
#
# File ~/Documents/Projects/robo-review/models/classifiers/classifier_model_linearSVC.py:23, in run_sentiment_pipeline()
#      22 def run_sentiment_pipeline():
# ---> 23     df = load_and_clean_data()
#      24     if df.empty:
#      25         print("\nCould not find data files. Please ensure the CSVs are in the correct directory.")
#
# File ~/Documents/Projects/robo-review/utils/dataframe.py:18, in load_and_clean_data()
#      11 source_names = [
#      12     "1429_1.csv",
#      13     "Datafiniti_Amazon_Consumer_Reviews_of_Amazon_Products.csv",
#      14     "Datafiniti_Amazon_Consumer_Reviews_of_Amazon_Products_May19.csv"
#      15 ]
#      17 # Clean the data using the data_cleaner function
# ---> 18 cleaned_df = data_cleaner(df_list, source_names)
#      20 return cleaned_df
#
# File ~/Documents/Projects/robo-review/utils/data_cleaner.py:79, in data_cleaner(df_list, source_names)
#      75 # 3. Remove duplicate reviews
#      76 # We define a duplicate as a review with the same product, rating, title, AND text.
#      77 # We use the 'MUST_HAVE_COLUMNS' as they are the most reliable identifiers.
#      78 original_count = len(merged_df)
# ---> 79 merged_df = merged_df.drop_duplicates(subset=MUST_HAVE_COLUMNS, keep='first')
#      80 new_count = len(merged_df)
#      81 print(f"Dropped {original_count - new_count} duplicate reviews.")
#
# File /opt/homebrew/lib/python3.10/site-packages/pandas/core/frame.py:6840, in DataFrame.drop_duplicates(self, subset, keep, inplace, ignore_index)
#    6837 inplace = validate_bool_kwarg(inplace, "inplace")
#    6838 ignore_index = validate_bool_kwarg(ignore_index, "ignore_index")
# -> 6840 result = self[-self.duplicated(subset, keep=keep)]
#    6841 if ignore_index:
#    6842     result.index = default_index(len(result))
#
# File /opt/homebrew/lib/python3.10/site-packages/pandas/core/frame.py:6980, in DataFrame.duplicated(self, subset, keep)
#    6978 else:
#    6979     vals = (col.values for name, col in self.items() if name in subset)
# -> 6980     labels, shape = map(list, zip(*map(f, vals)))
#    6982     ids = get_group_index(labels, tuple(shape), sort=False, xnull=False)
#    6983     result = self._constructor_sliced(duplicated(ids, keep), index=self.index)
#
# File /opt/homebrew/lib/python3.10/site-packages/pandas/core/frame.py:6948, in DataFrame.duplicated.<locals>.f(vals)
#    6947 def f(vals) -> tuple[np.ndarray, int]:
# -> 6948     labels, shape = algorithms.factorize(vals, size_hint=len(self))
#    6949     return labels.astype("i8", copy=False), len(shape)
#
# File /opt/homebrew/lib/python3.10/site-packages/pandas/core/algorithms.py:795, in factorize(values, sort, use_na_sentinel, size_hint)
#     792             # Don't modify (potentially user-provided) array
#     793             values = np.where(null_mask, na_value, values)
# --> 795     codes, uniques = factorize_array(
#     796         values,
#     797         use_na_sentinel=use_na_sentinel,
#     798         size_hint=size_hint,
#     799     )
#     801 if sort and len(uniques) > 0:
#     802     uniques, codes = safe_sort(
#     803         uniques,
#     804         codes,
#    (...)
#     807         verify=False,
#     808     )
#
# File /opt/homebrew/lib/python3.10/site-packages/pandas/core/algorithms.py:595, in factorize_array(values, use_na_sentinel, size_hint, na_value, mask)
#     592 hash_klass, values = _get_hashtable_algo(values)
#     594 table = hash_klass(size_hint or len(values))
# --> 595 uniques, codes = table.factorize(
#     596     values,
#     597     na_sentinel=-1,
#     598     na_value=na_value,
#     599     mask=mask,
#     600     ignore_na=use_na_sentinel,
#     601 )
#     603 # re-cast e.g. i8->dt64/td64, uint8->bool
#     604 uniques = _reconstruct_data(uniques, original.dtype, original)
#
# KeyboardInterrupt:
