# %%
# 1. Install missing dependencies
# %pip install google-genai python-dotenv pandas

# 2. Adjust system path (assuming current notebook location is correct)
import sys, os
# Adjust levels to reach the project root
sys.path.append(os.path.abspath('../../..')) 

# 3. Import and execute the function
# This line will now succeed as 'google' and 'dotenv' are installed,
# and the path to 'summarization_gemini.py' is correctly set.
from models.summarizers.summarization_gemini import generate_recommendation_article_from_clusters

# Execute the main function
# Note: You should pass the correct path to your results directory, 
# which is often relative to the project root.
# Assuming your results folder is at the root:
# project_root_path = os.path.abspath('../../..')
# results_folder_path = os.path.join(project_root_path, 'results')
# final_article = generate_recommendation_article_from_clusters(results_folder_path)

# For a typical setup where the notebook is run from a subfolder and 'results' 
# is at the root:
final_article = generate_recommendation_article_from_clusters('../../../results')

print("Attempting to run article generation pipeline...")
# The function will print its progress and the final save location.
# Out:
# ERROR: Invalid requirement: 'google-genai,'
#
# [notice] A new release of pip available: 22.2.2 -> 25.3
# [notice] To update, run: python3.10 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 4
#       2 import sys, os
#       3 sys.path.append(os.path.abspath('../../..'))
# ----> 4 from models.summarizers.summarization_gemini import generate_recommendation_article_from_clusters
#
# File ~/Documents/Projects/robo-review/models/summarizers/summarization_gemini.py:4
#       2 import os
#       3 import sys
# ----> 4 from google import genai
#       5 from google.genai.errors import APIError
#       6 from dotenv import load_dotenv # Importa a biblioteca para carregar o .env
#
# ModuleNotFoundError: No module named 'google'

# %%
generate_recommendation_article_from_clusters('../../../results')
# Out:
# ...
# STARTING SUMMARIZATION PIPELINE (BART Large CNN)
# ...
# Loaded summarization data: 65786 reviews.
# config.json: 0.00B [00:00, ?B/s]
# model.safetensors:   0%|          | 0.00/1.63G [00:00<?, ?B/s]
# Cancellation requested; stopping current tasks.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File /opt/homebrew/lib/python3.10/site-packages/huggingface_hub/file_download.py:626, in xet_get(incomplete_path, xet_file_data, headers, expected_size, displayed_filename, _tqdm_bar)
#     624     progress.update(progress_bytes)
# --> 626 download_files(
#     627     xet_download_info,
#     628     endpoint=connection_info.endpoint,
#     629     token_info=(connection_info.access_token, connection_info.expiration_unix_epoch),
#     630     token_refresher=token_refresher,
#     631     progress_updater=[progress_updater],
#     632 )
#
# KeyboardInterrupt:
#
# ...
